# %% [markdown]
# #### Interview Question and answer by ACC(Applied Cloud Computing)

# %%
import pandas as pd

df=pd.read_excel('/content/interview_data.xlsx')

# %%
df
# Out:
#      employee_id         employee_name  department state  salary  age  bonus
# 0           1000             Nitz Leif   Marketing    CA    6131   26    543
# 1           1001       Melissia Dedman     Finance    AK    4027   43   1290
# 2           1002     Rudolph Barringer          HR    LA    3122   43   1445
# 3           1003           Tamra Amber    Accounts    AK    5717   47   1291
# 4           1004           Mullan Nitz  Purchasing    CA    5685   34   1394
# ..           ...                   ...         ...   ...     ...  ...    ...
# 995         1995        Dionne Sifford       Sales    WA    6647   35    984
# 996         1996          Megan Coogan       Sales    NY    8260   33   1938
# 997         1997  Jacquelyne Barringer     Finance    CA    9899   22    837
# 998         1998      Casimira Ruzicka    Accounts    NY    2661   43   1128
# 999         1999          Dionne Gilma          HR    LA    8389   50   1829
#
# [1000 rows x 7 columns]

# %%
##create new columns having value is sum of salary and bonus
df['total_amount']=df['salary']+df['bonus']
df
# Out:
#      employee_id         employee_name  department state  salary  age  bonus  \
# 0           1000             Nitz Leif   Marketing    CA    6131   26    543
# 1           1001       Melissia Dedman     Finance    AK    4027   43   1290
# 2           1002     Rudolph Barringer          HR    LA    3122   43   1445
# 3           1003           Tamra Amber    Accounts    AK    5717   47   1291
# 4           1004           Mullan Nitz  Purchasing    CA    5685   34   1394
# ..           ...                   ...         ...   ...     ...  ...    ...
# 995         1995        Dionne Sifford       Sales    WA    6647   35    984
# 996         1996          Megan Coogan       Sales    NY    8260   33   1938
# 997         1997  Jacquelyne Barringer     Finance    CA    9899   22    837
# 998         1998      Casimira Ruzicka    Accounts    NY    2661   43   1128
# 999         1999          Dionne Gilma          HR    LA    8389   50   1829
#
#      total_amount
# 0            6674
# ...

# %%
#maximum salary department wise
df.groupby('department')['salary'].max()
# Out:
# department
# Accounts      9890
# Finance       9899
# HR            9982
# Marketing     9974
# Purchasing    9985
# Sales         9982
# Name: salary, dtype: int64

# %%
def max_salary_value(group):
  return group.loc[group['salary'].idxmax()]

max_scores = df.groupby('department').apply(max_salary_value)
max_scores
# Out:
#             employee_id         employee_name  department state  salary  age  \
# department
# Accounts           1760         Vankirk Grigg    Accounts    WA    9890   35
# Finance            1997  Jacquelyne Barringer     Finance    CA    9899   22
# HR                 1475         Harrison Nitz          HR    WA    9982   43
# Marketing          1063      Vivan Jacquelyne   Marketing    LA    9974   35
# Purchasing         1762          Amber Ullery  Purchasing    CA    9985   47
# Sales              1088           Imai Locust       Sales    NY    9982   49
#
#             bonus  total_amount
# department
# Accounts     1762         11652
# Finance       837         10736
# HR           1362         11344
# Marketing     823         10797
# Purchasing   1408         11393
# Sales        1809         11791

# %%
data={
  "apiinsights": {
    "aliases": {},
    "mappings": {
      "properties": {
        "apiFormat": {
          "type": "text",
          "fields": {
            "keyword": {
              "type": "keyword",
              "ignore_above": 256
            }
          }
        },
        "api_id": {
          "type": "keyword"
        },
        "api_name": {
          "type": "text",
          "fields": {
            "keyword": {
              "type": "keyword",
              "ignore_above": 256
            }
          }
        },
        "api_vendor": {
          "type": "text",
          "fields": {
            "keyword": {
              "type": "keyword",
              "ignore_above": 256
            }
          }
        },
        "application_id": {
          "type": "keyword"
        },
        "atlas_request_id": {
          "type": "keyword"
        },
        "consumed_by": {
          "type": "keyword"
        },
        "createdAt": {
          "type": "date",
          "format": "yyyy-MM-dd HH:mm:ss"
        },
        "duration": {
          "type": "long"
        },
        "id": {
          "type": "keyword"
        },
        "ip": {
          "type": "ip"
        },
        "loan_number": {
          "type": "text",
          "fields": {
            "keyword": {
              "type": "keyword",
              "ignore_above": 256
            }
          }
        },
        "normalized_request_timestamp": {
          "type": "text",
          "fields": {
            "keyword": {
              "type": "keyword",
              "ignore_above": 256
            }
          }
        },
        "query": {
          "properties": {
            "bool": {
              "properties": {
                "filter": {
                  "properties": {
                    "range": {
                      "properties": {
                        "createdAt": {
                          "properties": {
                            "gte": {
                              "type": "text",
                              "fields": {
                                "keyword": {
                                  "type": "keyword",
                                  "ignore_above": 256
                                }
                              }
                            },
                            "lte": {
                              "type": "text",
                              "fields": {
                                "keyword": {
                                  "type": "keyword",
                                  "ignore_above": 256
                                }
                              }
                            }
                          }
                        }
                      }
                    }
                  }
                }
              }
            }
          }
        },
        "status_code": {
          "type": "integer"
        },
        "success": {
          "type": "boolean"
        },
        "updatedAt": {
          "type": "date",
          "format": "yyyy-MM-dd HH:mm:ss"
        }
      }
    },
    "settings": {
      "index": {
        "creation_date": "1690507156254",
        "number_of_shards": "1",
        "number_of_replicas": "1",
        "uuid": "rtW2iOTuRxqt5wuFFE7fDg",
        "version": {
          "created": "136287827"
        },
        "provided_name": "apiinsights"
      }
    }
  }
}

# %%
data['apiinsights']['settings']['index']['creation_date']
# Out:
# '1690507156254'
